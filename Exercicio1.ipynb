# %%
import pandas as pd

# %%
urls = ['http://servicodados.ibge.gov.br/Download/Download.ashx?u=ftp.ibge.gov.br/Acesso_a_internet_e_posse_celular/2013/tabelas_xls/01pessoas/02equipamentos.xls']

pd.read_excel(urls[0], sheet_name='Tab 1.2.1.1 e 1.2.1.2', skiprows=4,index_col=0, skip_footer=2, usecols=range(0,7))
# Out:
#                                           Unnamed: 1     Norte   Nordeste  \
# Total                                      85572.059  5376.929  17578.931
# Microcomputador                                  NaN       NaN        NaN
# Utilizaram                                 78343.998  4173.648  15867.015
# Somente microcomputador                    43478.100  1860.163   9251.458
# Não utilizaram                              7228.061  1203.281   1711.916
# Telefone móvel celular ou tablet                 NaN       NaN        NaN
# Utilizaram                                 41682.853  3489.957   8266.832
# Somente telefone móvel celular ou tablet    6896.053  1178.267   1662.591
# Não utilizaram                             43889.206  1886.972   9312.099
# Telefone móvel celular                           NaN       NaN        NaN
# Utilizaram                                 39364.933  3438.935   7846.538
# Somente telefone móvel celular              6278.647  1146.452   1514.297
# ...
